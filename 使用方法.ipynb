# %% [markdown]
# ### 一、安装EmQuantAPI

# %% [markdown]
# 1. 在[Choice数据量化接口平台](http://quantapi.eastmoney.com/)中获得API使用权限
# 2. 下载安装包![图片.png](attachment:aa119920-3d7f-4d7f-8131-6f2a268ae443.png)
# 3. 安装![图片.png](attachment:64bae57d-f9d8-498e-852b-994b146b2b70.png)![图片.png](attachment:018bcc3e-823b-4ec0-b0bc-b2e049c0662f.png)![图片.png](attachment:daa5446b-a42f-45b1-8cd0-4a6a257e9d40.png)![图片.png](attachment:785e589e-39c0-4025-a46a-8fbf814d55f1.png)![图片.png](attachment:a62a99de-92ba-49b2-b1af-d8d754fa05cf.png)

# %%
from Get_Data_Choice import get_data  # 在使用该模块前需安装EmQuantAPI
from Financial_Statement_Analysis import PlotAll, ExtraPlot

# %%
ticker = '001979.SH'  # 定义股票代码（xxxxxx.SZ 或 xxxxxx.SH）
start_year = 2017  # 起始年份
period = 5  # 时间跨度

# %%
get_data(ticker=ticker, start_year=start_year, period=period)  # 获取数据
# Out:
# [EmQuantAPI Python] [Em_Info][2022-07-28 22:30:04]:The current version is EmQuantAPI(V2.5.4.0).
#
# [EmQuantAPI Python] [Em_Info][2022-07-28 22:30:04]:verifying your token...
#
# [EmQuantAPI Python] [Em_Info][2022-07-28 22:30:04]:connect server...
# 2022-07-28 22:30:05,865 22376 INFO Get_Data_Choice - ErrorCode=0, ErrorMsg=success, Data={}
# [EmQuantAPI Python] [Em_Info][2022-07-28 22:30:05]:start success!
# 2022-07-28 22:30:05,866 22376 INFO Get_Data_Choice - 登陆成功！
# 2022-07-28 22:30:05,867 22376 INFO Get_Data_Choice - 开始请求现金流量表数据 2016-12-31
# 2022-07-28 22:30:05,934 22376 INFO Get_Data_Choice - 请求现金流量表数据成功 2016-12-31
# 2022-07-28 22:30:05,935 22376 INFO Get_Data_Choice - 开始请求现金流量表数据 2017-12-31
# 2022-07-28 22:30:05,998 22376 INFO Get_Data_Choice - 请求现金流量表数据成功 2017-12-31
# 2022-07-28 22:30:06,000 22376 INFO Get_Data_Choice - 开始请求现金流量表数据 2018-12-31
# 2022-07-28 22:30:06,068 22376 INFO Get_Data_Choice - 请求现金流量表数据成功 2018-12-31
# ...

# %%
PlotAll(ticker).plot()  # 绘制分析图
# Out:
# 2022-07-28 22:30:06,259 22376 ERROR Financial_Statement_Analysis - [Errno 2] No such file or directory: '.\\\\data\\\\001979.SH_公司资料.csv'

# %%
ticker_example = '601857.SH'  # 中国石油
ExtraPlot(ticker_example).plot()
